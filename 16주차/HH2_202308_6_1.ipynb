# %% [markdown]
# ## 플릭커+CNN
# - 아래 내용을 실행해보세요
# - 플릭커 api key, secret값이 필요
# - 인공신경망 구조를 변경해보세요
# - dnn, cnn 성능을 비교해보세요

# %%
# !pip install flickrapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# - 원하는 종류의 사진별 수집, 각각의 폴더에 이미지 저장
#  - 첫 번째 범주에 해당하는 이미지 수집

# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

key="9a40cdd652eb1375862ce11430f0ead3"
secret="e2457d0007618967"

wait_time=1

#사진 검색 및 저장
savedir="apple"
if not os.path.exists(savedir):
 os.mkdir(savedir)

#API로 다운로드
flickr = FlickrAPI(key, secret, format="parsed-json")
res=flickr.photos.search( text="사과", per_page=100, media="photos", sort="relevance", safe_search=1, extras="url_q, license")

photos=res['photos']
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 13,
#  'perpage': 100,
#  'photo': [{'farm': 66,
#             'height_q': 150,
#             'id': '52480883795',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '187215326@N03',
#             'secret': 'e1901190a2',
#             'server': '65535',
#             'title': '사과',
#             'url_q': 'https://live.staticflickr.com/65535/52480883795_e1901190a2_q.jpg',
#             'width_q': 150},
#            {'farm': 6,
#             'height_q': 150,
#             'id': '15451299909',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '31942773@N04',
#             'secret': 'e7a5c34dd1',
#             'server': '5612',
#             'title': '사과',
#             'url_q': 'https://live.staticflickr.com/5612/15451299909_e7a5c34dd1_q.jpg',
#             'width_q': 150},
# ...

# %% [markdown]
# - 이미지 url로 이미지 저장
# - 2개 이상의 키워드로 플릭커에서 위의 코드를 이용하셔서 이미지를 수집해보세요.

# %%
try:
 for i , photo in enumerate(photos['photo']):
  url_q = photo['url_q']
  filepath = savedir+'/'+photo['id']+'.jpg'
  if os.path.exists(filepath):continue
  print(str(i+1)+":download=", url_q)
  urlretrieve(url_q, filepath)
  time.sleep(wait_time)
except:
 import traceback
 traceback.print_exc()
# Out:
# 1:download= https://live.staticflickr.com/65535/52480883795_e1901190a2_q.jpg
# 2:download= https://live.staticflickr.com/5612/15451299909_e7a5c34dd1_q.jpg
# 3:download= https://live.staticflickr.com/7311/9471005625_2a26634037_q.jpg
# 4:download= https://live.staticflickr.com/4044/4342454158_2f18bfbb5a_q.jpg
# 5:download= https://live.staticflickr.com/3134/2915185764_54853f3bab_q.jpg
# 6:download= https://live.staticflickr.com/3064/2915188928_cb7efd7980_q.jpg
# 7:download= https://live.staticflickr.com/3703/9370689960_47d69323ee_q.jpg
# 8:download= https://live.staticflickr.com/2605/4046853726_c7bee18430_q.jpg
# 9:download= https://live.staticflickr.com/6050/6850311570_e43e27dabf_q.jpg
# 10:download= https://live.staticflickr.com/7353/10830541544_87e76a7d2a_q.jpg
# 11:download= https://live.staticflickr.com/8459/8025806183_7cb867eaf1_q.jpg
# 12:download= https://live.staticflickr.com/2745/4043310969_dd0b5f42e1_q.jpg
# ...

# %%
#flick 사진 처리
import numpy as np
from PIL import Image
import os, glob, random

max_photo = 100
photo_size=32
x=[]
y=[]

files = glob.glob( "apple"+"/*.jpg")
random.shuffle(files)

num=0

for f in files:
 if num >= max_photo: break
 num +=1
 img = Image.open(f)
 img= img.convert("RGB")
 img= img.resize((photo_size, photo_size))
 img= np.asarray(img)
 x.append(img)
 y.append(0)	#label을 0으로 지정


#이미지 출력
import matplotlib.pyplot as plt
idx = 0
plt.figure(figsize=(10,10))
for i in range(25):
 plt.subplot(5,5,i+1)
 plt.title(y[i+idx])
 plt.imshow(x[i+idx])
plt.show()

# %% [markdown]
#   - 두 번째 범주의 이미지 수집

# %%
from flickrapi import FlickrAPI
from urllib.request import urlretrieve
from pprint import pprint
import os, time, sys

key="9a40cdd652eb1375862ce11430f0ead3"
secret="e2457d0007618967"

wait_time=1

#사진 검색 및 저장
savedir="pear"
if not os.path.exists(savedir):
 os.mkdir(savedir)

#API로 다운로드
flickr = FlickrAPI(key, secret, format="parsed-json")
res=flickr.photos.search( text="고양이", per_page=100, media="photos", sort="relevance", safe_search=1, extras="url_q, license")

photos=res['photos']
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 258,
#  'perpage': 100,
#  'photo': [{'farm': 4,
#             'height_q': 150,
#             'id': '3506613091',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '14964164@N03',
#             'secret': '588e331b6f',
#             'server': '3339',
#             'title': '고양이',
#             'url_q': 'https://live.staticflickr.com/3339/3506613091_588e331b6f_q.jpg',
#             'width_q': 150},
#            {'farm': 4,
#             'height_q': 150,
#             'id': '3506613379',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'license': '0',
#             'owner': '14964164@N03',
#             'secret': '18b8c5a0c0',
#             'server': '3409',
#             'title': '고양이',
#             'url_q': 'https://live.staticflickr.com/3409/3506613379_18b8c5a0c0_q.jpg',
#             'width_q': 150},
# ...

# %%
try:
 for i , photo in enumerate(photos['photo']):
  url_q = photo['url_q']
  filepath = savedir+'/'+photo['id']+'.jpg'
  if os.path.exists(filepath):continue
  print(str(i+1)+":download=", url_q)
  urlretrieve(url_q, filepath)
  time.sleep(wait_time)
except:
 import traceback
 traceback.print_exc()
# Out:
# 1:download= https://live.staticflickr.com/3339/3506613091_588e331b6f_q.jpg
# 2:download= https://live.staticflickr.com/3409/3506613379_18b8c5a0c0_q.jpg
# 3:download= https://live.staticflickr.com/7101/6984547900_71493a1d3c_q.jpg
# 4:download= https://live.staticflickr.com/5735/23638646061_7043d4ee11_q.jpg
# 5:download= https://live.staticflickr.com/3220/2697595751_3c96ee6132_q.jpg
# 6:download= https://live.staticflickr.com/5647/21515539123_42790bf36c_q.jpg
# 7:download= https://live.staticflickr.com/7551/15746475512_8d322dc960_q.jpg
# 8:download= https://live.staticflickr.com/5721/21837925993_922e2e4ee6_q.jpg
# 9:download= https://live.staticflickr.com/650/21515532383_c89b047d14_q.jpg
# 10:download= https://live.staticflickr.com/65535/51032530146_8ccae87490_q.jpg
# 11:download= https://live.staticflickr.com/620/21897770358_95be4aa119_q.jpg
# 12:download= https://live.staticflickr.com/7100/7305368552_b391a2de09_q.jpg
# ...

# %%
#flick 사진 처리
max_photo = 100
photo_size=32

files = glob.glob( "pear"+"/*.jpg")
random.shuffle(files)

num=0

for f in files:
 if num >= max_photo: break
 num +=1
 img = Image.open(f)
 img= img.convert("RGB")
 img= img.resize((photo_size, photo_size))
 img= np.asarray(img)
 x.append(img)
 y.append(1)	#label을 0으로 지정


#이미지 출력
import matplotlib.pyplot as plt
idx = 0
plt.figure(figsize=(10,10))
for i in range(25):
 plt.subplot(5,5,i+1)
 plt.title(y[i+idx])
 plt.imshow(x[i+idx])
plt.show()

# %%
x = np.array(x)
y = np.array(y)
x.shape
# Out:
# (200, 32, 32, 3)

# %% [markdown]
# 3. DNN 적용하기

# %%
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization, Activation
from sklearn.model_selection import train_test_split

num_classes = 2
im_rows = 32
im_cols = 32
im_size = im_rows * im_cols * 3

# 데이터 읽어 들이기
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.3)

# %%
# 데이터를 1차원 배열로 변환하기
X_train = X_train.reshape(-1, im_size).astype('float32') / 255 #평탄화->소숫점있는숫자->스케일링
X_test = X_test.reshape(-1, im_size).astype('float32') / 255
# 타겟변수를 One-hot 형식으로 변환하기
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

X_train.shape
y_train.shape
# Out:
# (140, 2)

# %%
#실행 전 GPU 설정
# 모델 정의하기
model = Sequential()
model.add(Dense(1024, input_shape=(im_size,)))
model.add(BatchNormalization())  # 배치별 다른 입력 데이터 분포를 정규화(normalize),  활성화 함수를 적용하기 전 스케일링(scale) 및 이동(shift)을 수행
model.add(Activation("relu"))

model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation("relu"))

model.add(Dense(128))
model.add(BatchNormalization())
model.add(Activation("relu"))

model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation("relu"))

model.add(Dense(num_classes))
model.add(BatchNormalization())
model.add(Activation("softmax"))


# 모델 컴파일하기
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

# 학습 실행하기
hist = model.fit(X_train, y_train,
    batch_size=32, epochs=30,
    verbose=1,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 5/5 [==============================] - 3s 124ms/step - loss: 0.7957 - accuracy: 0.5786 - val_loss: 2.8313 - val_accuracy: 0.4667
# Epoch 2/10
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3895 - accuracy: 0.8571 - val_loss: 5.1676 - val_accuracy: 0.4667
# Epoch 3/10
# 5/5 [==============================] - 0s 56ms/step - loss: 0.3133 - accuracy: 0.9071 - val_loss: 3.5540 - val_accuracy: 0.4667
# Epoch 4/10
# 5/5 [==============================] - 0s 58ms/step - loss: 0.2491 - accuracy: 0.9714 - val_loss: 3.9447 - val_accuracy: 0.4667
# Epoch 5/10
# 5/5 [==============================] - 0s 60ms/step - loss: 0.2387 - accuracy: 0.9643 - val_loss: 2.1430 - val_accuracy: 0.4833
# Epoch 6/10
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2000 - accuracy: 0.9857 - val_loss: 3.1180 - val_accuracy: 0.4833
# Epoch 7/10
# ...

# %%
# 모델 평가하기
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 2/2 [==============================] - 0s 18ms/step - loss: 1.8047 - accuracy: 0.5167
# 정답률= 0.5166666507720947 loss= 1.80465567111969

# %%
# 학습 상태를 그래프로 그리기
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# 4. CNN 적용하기

# %%
import matplotlib.pyplot as plt
import keras
import tensorflow as tf
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam

num_classes = 10
im_rows = 32
im_cols = 32
in_shape = (im_rows, im_cols, 3)

# 데이터 읽어 들이기
X_train, X_test, y_train, y_test = train_test_split( x, y, test_size=0.3)

# 데이터를 정규화하기 (flatten을 하지 않음)
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
# 레이블 데이터를 One-hot 형식으로 변환하기
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# 모델 정의하기
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', input_shape=in_shape))
model.add(BatchNormalization())
model.add(Activation("relu"))

model.add(Conv2D(32, (3, 3)))
model.add(BatchNormalization())
model.add(Activation("relu"))

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation("relu"))

model.add(Conv2D(64, (3, 3)))
model.add(BatchNormalization())
model.add(Activation("relu"))

model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation("relu"))

model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(BatchNormalization())
model.add(Activation("softmax"))

# %%
#실행 전 GPU 설정
# 모델 컴파일하기
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(0.0005),
    metrics=['accuracy'])

# 학습 실행하기
hist = model.fit(X_train, y_train,
    batch_size=32, epochs=30,
    verbose=1,
    validation_split=0.1)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 3s 361ms/step - loss: 2.6436 - accuracy: 0.0952 - val_loss: 2.2386 - val_accuracy: 0.5714
# Epoch 2/10
# 4/4 [==============================] - 1s 191ms/step - loss: 2.2964 - accuracy: 0.1429 - val_loss: 2.2426 - val_accuracy: 0.5714
# Epoch 3/10
# 4/4 [==============================] - 1s 193ms/step - loss: 2.1977 - accuracy: 0.1587 - val_loss: 2.2753 - val_accuracy: 0.5714
# Epoch 4/10
# 4/4 [==============================] - 1s 184ms/step - loss: 2.0982 - accuracy: 0.1984 - val_loss: 2.2516 - val_accuracy: 0.5000
# Epoch 5/10
# 4/4 [==============================] - 1s 183ms/step - loss: 1.9740 - accuracy: 0.2937 - val_loss: 2.1956 - val_accuracy: 0.5000
# Epoch 6/10
# 4/4 [==============================] - 1s 202ms/step - loss: 1.9294 - accuracy: 0.3492 - val_loss: 2.1269 - val_accuracy: 0.5714
# Epoch 7/10
# ...

# %%
# 모델 평가하기
score = model.evaluate(X_test, y_test, verbose=1)
print('정답률=', score[1], 'loss=', score[0])
# Out:
# 2/2 [==============================] - 0s 39ms/step - loss: 1.9295 - accuracy: 0.5500
# 정답률= 0.550000011920929 loss= 1.9295262098312378
